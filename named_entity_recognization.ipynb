# %%
sentence = "The Eiffel Tower was built from 1887 to 1889 by Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')

words=nltk.word_tokenize(sentence)

# %%
tag_element = nltk.pos_tag(words)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/palak/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
# Required above by nltk.ne_chunk(tag_element)
# Out:
# [nltk_data] Downloading package words to /Users/palak/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
named_entity_tree = nltk.ne_chunk(tag_element)
print(named_entity_tree)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 nltk.ne_chunk(tag_element).draw()
#
# File ~/Desktop/Project/NLP-practical/NLPenv/lib/python3.10/site-packages/nltk/chunk/__init__.py:192, in ne_chunk(tagged_tokens, binary)
#     190     chunker = ne_chunker(fmt="binary")
#     191 else:
# --> 192     chunker = ne_chunker()
#     193 return chunker.parse(tagged_tokens)
#
# File ~/Desktop/Project/NLP-practical/NLPenv/lib/python3.10/site-packages/nltk/chunk/__init__.py:174, in ne_chunker(fmt)
#     170 def ne_chunker(fmt="multiclass"):
#     171     """
#     172     Load NLTK's currently recommended named entity chunker.
#     173     """
# --> 174     return Maxent_NE_Chunker(fmt)
#
# File ~/Desktop/Project/NLP-practical/NLPenv/lib/python3.10/site-packages/nltk/chunk/named_entity.py:328, in Maxent_NE_Chunker.__init__(self, fmt)
#     325 def __init__(self, fmt="multiclass"):
#     327     self._fmt = fmt
# --> 328     self._tab_dir = find(f"chunkers/maxent_ne_chunker_tab/english_ace_{fmt}/")
#     329     self.load_params()
#
# File ~/Desktop/Project/NLP-practical/NLPenv/lib/python3.10/site-packages/nltk/data.py:738, in find(resource_name, paths)
#     736 sep = "*" * 70
#     737 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 738 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'maxent_ne_chunker_tab' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('maxent_ne_chunker_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'chunkers/maxent_ne_chunker_tab/english_ace_multiclass/'
#
#   Searched in:
#     - '/Users/palak/nltk_data'
#     - '/Users/palak/Desktop/Project/NLP-practical/NLPenv/nltk_data'
#     - '/Users/palak/Desktop/Project/NLP-practical/NLPenv/share/nltk_data'
#     - '/Users/palak/Desktop/Project/NLP-practical/NLPenv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
